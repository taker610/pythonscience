# %% [markdown]
# # XML example and exercise
# ****
# + study examples of accessing nodes in XML tree structure
# + work on exercise to be completed and submitted
# ****
# + reference: https://docs.python.org/2.7/library/xml.etree.elementtree.html
# + data source: http://www.dbis.informatik.uni-goettingen.de/Mondial
# ****

# %%
from xml.etree import ElementTree as ET

# %% [markdown]
# ## XML example
#
# + for details about tree traversal and iterators, see https://docs.python.org/2.7/library/xml.etree.elementtree.html

# %%
document_tree = ET.parse( './data/mondial_database_less.xml' )

# %%
# print names of all countries
for child in document_tree.getroot():
    print child.find('name').text
# Out:
# Albania
# Greece
# Macedonia
# Serbia
# Montenegro
# Kosovo
# Andorra

# %%
# print names of all countries and their cities
for element in document_tree.iterfind('country'):
    print '* ' + element.find('name').text + ':',
    capitals_string = ''
    for subelement in element.getiterator('city'):
        capitals_string += subelement.find('name').text + ', '
    print capitals_string[:-2]
# Out:
# * Albania: Tirana, Shkodër, Durrës, Vlorë, Elbasan, Korçë
# * Greece: Komotini, Kavala, Athina, Peiraias, Peristeri, Acharnes, Patra, Kozani, Kerkyra, Ioannina, Thessaloniki, Iraklio, Chania, Ermoupoli, Rhodes, Tripoli, Lamia, Chalkida, Larissa, Volos, Mytilini, Karyes
# * Macedonia: Skopje, Kumanovo
# * Serbia: Beograd, Novi Sad, Niš
# * Montenegro: Podgorica
# * Kosovo: Prishtine
# * Andorra: Andorra la Vella

# %% [markdown]
# ****
# ## XML exercise
#
# Using data in 'data/mondial_database.xml', the examples above, and refering to https://docs.python.org/2.7/library/xml.etree.elementtree.html, find
#
# 1. 10 countries with the lowest infant mortality rates
# 2. 10 cities with the largest population
# 3. 10 ethnic groups with the largest overall populations (sum of best/latest estimates over all countries)
# 4. name and country of a) longest river, b) largest lake and c) airport at highest elevation

# %%
from xml.etree import ElementTree as ET
document = ET.parse( 'C:\data_wrangling_xml/mondial_database.xml' )

# %%
from operator import itemgetter, attrgetter, methodcaller

# %% [markdown]
# Solution 1

# %%
data = []
for element in document.iterfind('country'):
    name = element.find('name').text
    if element.find('infant_mortality') is None:
        rate = None
    else:
        rate = float(element.find('infant_mortality').text)
    data.append((rate,name))
        
sorted(data, key=itemgetter(0))
# Out:
# [(None, 'Montenegro'),
#  (None, 'Kosovo'),
#  (None, 'Holy See'),
#  (None, 'Ceuta'),
#  (None, 'Melilla'),
#  (None, 'Svalbard'),
#  (None, 'Christmas Island'),
#  (None, 'Cocos Islands'),
#  (None, 'Curacao'),
#  (None, 'Saint Martin'),
#  (None, 'Saint Barthelemy'),
#  (None, 'Niue'),
#  (None, 'Norfolk Island'),
#  (None, 'Pitcairn'),
#  (None, 'Tokelau'),
#  (None, 'Falkland Islands'),
#  (1.81, 'Monaco'),
#  (2.13, 'Japan'),
#  (2.48, 'Norway'),
#  (2.48, 'Bermuda'),
#  (2.53, 'Singapore'),
#  (2.6, 'Sweden'),
#  (2.63, 'Czech Republic'),
#  (2.73, 'Hong Kong'),
#  (3.13, 'Macao'),
#  (3.15, 'Iceland'),
#  (3.31, 'France'),
#  (3.31, 'Italy'),
#  (3.33, 'Spain'),
#  (3.36, 'Finland'),
#  (3.4, 'Anguilla'),
#  (3.46, 'Germany'),
#  (3.47, 'Guernsey'),
#  (3.59, 'Malta'),
#  (3.64, 'Belarus'),
#  (3.66, 'Netherlands'),
#  (3.69, 'Andorra'),
#  (3.73, 'Switzerland'),
#  (3.74, 'Ireland'),
#  (3.86, 'Jersey'),
#  (3.93, 'South Korea'),
#  (3.98, 'Israel'),
#  (4.04, 'Slovenia'),
#  (4.1, 'Denmark'),
#  (4.16, 'Austria'),
#  (4.17, 'Isle of Man'),
#  (4.18, 'Belgium'),
#  (4.28, 'Luxembourg'),
#  (4.33, 'Liechtenstein'),
#  (4.43, 'Australia'),
#  (4.44, 'United Kingdom'),
#  (4.48, 'Portugal'),
#  (4.49, 'Taiwan'),
#  (4.49, 'Wallis and Futuna'),
#  (4.52, 'San Marino'),
#  (4.59, 'New Zealand'),
#  (4.7, 'Cuba'),
#  (4.71, 'Canada'),
#  (4.78, 'Greece'),
#  (4.78, 'French Polynesia'),
#  (5.09, 'Hungary'),
#  (5.35, 'Slovakia'),
#  (5.46, 'New Caledonia'),
#  (5.5, 'Northern Mariana Islands'),
#  (5.51, 'Guam'),
#  (5.71, 'Faroe Islands'),
#  (5.84, 'Bosnia and Herzegovina'),
#  (5.87, 'Croatia'),
#  (6.0, 'Lithuania'),
#  (6.16, 'Serbia'),
#  (6.17, 'United States'),
#  (6.19, 'Poland'),
#  (6.21, 'Cayman Islands'),
#  (6.29, 'Gibraltar'),
#  (6.42, 'Qatar'),
#  (6.7, 'Estonia'),
#  (6.79, 'Virgin Islands'),
#  (6.95, 'Saint Pierre and Miquelon'),
#  (7.02, 'Chile'),
#  (7.08, 'Russia'),
#  (7.1, 'Martinique'),
#  (7.5, 'Reunion'),
#  (7.51, 'Kuwait'),
#  (7.73, 'Puerto Rico'),
#  (7.9, 'Macedonia'),
#  (7.91, 'Latvia'),
#  (7.98, 'Lebanon'),
#  (8.1, 'Ukraine'),
#  (8.21, 'Nauru'),
#  (8.3, 'Guadeloupe'),
#  (8.54, 'Cyprus'),
#  (8.7, 'Costa Rica'),
#  (8.92, 'American Samoa'),
#  (8.97, 'Uruguay'),
#  (8.98, 'Saint Kitts and Nevis'),
#  (9.02, 'Sri Lanka'),
#  (9.05, 'Sint Maarten'),
#  (9.38, 'Botswana'),
#  (9.42, 'Greenland'),
#  (9.68, 'Bahrain'),
#  (9.86, 'Thailand'),
#  (9.96, 'Argentina'),
#  (10.16, 'Romania'),
#  (10.2, 'Fiji'),
#  (10.48, 'Brunei'),
#  (10.5, 'Grenada'),
#  (10.59, 'Mauritius'),
#  (10.7, 'Panama'),
#  (10.77, 'Seychelles'),
#  (10.92, 'United Arab Emirates'),
#  (10.93, 'Barbados'),
#  (10.97, 'Turks and Caicos Islands'),
#  (11.46, 'Palau'),
#  (11.61, 'Dominica'),
#  (11.74, 'Aruba'),
#  (11.75, 'Saint Lucia'),
#  (11.87, 'Libya'),
#  (12.36, 'Tonga'),
#  (12.5, 'Bahamas'),
#  (12.58, 'Mexico'),
#  (12.93, 'Moldova'),
#  (13.07, 'Saint Vincent and the Grenadines'),
#  (13.19, 'Albania'),
#  (13.29, 'Antigua and Barbuda'),
#  (13.45, 'British Virgin Islands'),
#  (13.66, 'Montserrat'),
#  (13.69, 'Malaysia'),
#  (13.69, 'Jamaica'),
#  (13.97, 'Armenia'),
#  (14.0, 'Oman'),
#  (14.33, 'Cook Islands'),
#  (14.58, 'Saudi Arabia'),
#  (14.6, 'French Guiana'),
#  (14.79, 'China'),
#  (15.02, 'Colombia'),
#  (15.08, 'Bulgaria'),
#  (15.73, 'Jordan'),
#  (15.79, 'Syria'),
#  (16.17, 'Solomon Islands'),
#  (16.41, 'Vanuatu'),
#  (16.68, 'Georgia'),
#  (17.63, 'Saint Helena'),
#  (17.64, 'Philippines'),
#  (17.93, 'Ecuador'),
#  (18.44, 'El Salvador'),
#  (18.72, 'Honduras'),
#  (18.99, 'Vietnam'),
#  (19.21, 'Brazil'),
#  (19.33, 'Venezuela'),
#  (19.63, 'Dominican Republic'),
#  (19.84, 'Uzbekistan'),
#  (20.21, 'Peru'),
#  (20.31, 'Belize'),
#  (20.36, 'Nicaragua'),
#  (20.5, 'Samoa'),
#  (20.75, 'Paraguay'),
#  (21.39, 'Marshall Islands'),
#  (21.43, 'Turkey'),
#  (21.61, 'Kazakhstan'),
#  (21.76, 'Algeria'),
#  (21.93, 'Micronesia'),
#  (22.41, 'Egypt'),
#  (23.15, 'Mongolia'),
#  (23.19, 'Tunisia'),
#  (23.51, 'Guatemala'),
#  (24.28, 'Cape Verde'),
#  (24.5, 'North Korea'),
#  (24.52, 'Morocco'),
#  (24.59, 'Maldives'),
#  (24.82, 'Trinidad and Tobago'),
#  (25.16, 'Indonesia'),
#  (26.55, 'Zimbabwe'),
#  (26.67, 'Azerbaijan'),
#  (27.07, 'Suriname'),
#  (28.6, 'West Bank'),
#  (28.71, 'Kyrgyzstan'),
#  (30.6, 'Gaza Strip'),
#  (31.69, 'Tuvalu'),
#  (33.56, 'Guyana'),
#  (35.03, 'Tajikistan'),
#  (35.37, 'Kiribati'),
#  (37.53, 'Iraq'),
#  (37.89, 'Bhutan'),
#  (38.13, 'Turkmenistan'),
#  (38.44, 'Eritrea'),
#  (38.52, 'Ghana'),
#  (38.61, 'Bolivia'),
#  (38.79, 'Timor-Leste'),
#  (39.0, 'Iran'),
#  (39.67, 'Papua New Guinea'),
#  (40.43, 'Nepal'),
#  (40.71, 'Kenya'),
#  (41.61, 'South Africa'),
#  (43.19, 'India'),
#  (43.74, 'Tanzania'),
#  (44.88, 'Madagascar'),
#  (44.91, 'Myanmar'),
#  (45.64, 'Namibia'),
#  (45.67, 'Bangladesh'),
#  (46.73, 'Togo'),
#  (47.03, 'Gabon'),
#  (48.01, 'Malawi'),
#  (49.16, 'Sao Tome and Principe'),
#  (49.43, 'Haiti'),
#  (50.2, 'Djibouti'),
#  (50.41, 'Yemen'),
#  (50.48, 'Lesotho'),
#  (51.36, 'Cambodia'),
#  (52.72, 'Senegal'),
#  (52.86, 'Sudan'),
#  (54.53, 'Laos'),
#  (54.82, 'Swaziland'),
#  (55.1, 'Cameroon'),
#  (55.24, 'Guinea'),
#  (55.77, 'Ethiopia'),
#  (56.06, 'Mauritania'),
#  (56.29, 'Mayotte'),
#  (57.09, 'Benin'),
#  (57.48, 'Pakistan'),
#  (59.34, 'Congo'),
#  (59.59, 'Rwanda'),
#  (60.16, 'Cote dIvoire'),
#  (60.82, 'Uganda'),
#  (63.44, 'Burundi'),
#  (65.31, 'Comoros'),
#  (65.74, 'Gambia'),
#  (66.62, 'Zambia'),
#  (68.16, 'South Sudan'),
#  (69.19, 'Liberia'),
#  (71.12, 'Equatorial Guinea'),
#  (72.42, 'Mozambique'),
#  (73.15, 'Zaire'),
#  (73.29, 'Sierra Leone'),
#  (74.09, 'Nigeria'),
#  (76.8, 'Burkina Faso'),
#  (79.99, 'Angola'),
#  (86.27, 'Niger'),
#  (90.3, 'Chad'),
#  (90.92, 'Guinea-Bissau'),
#  (92.86, 'Central African Republic'),
#  (100.14, 'Somalia'),
#  (104.34, 'Mali'),
#  (117.23, 'Afghanistan'),
#  (145.82, 'Western Sahara')]

# %% [markdown]
# Solution 2

# %%
import unicodedata

def remove_diacritic(input):
    '''
    Accept a unicode string, and return a normal string (bytes in Python 3)
    without any diacritical marks.
    '''
    return unicodedata.normalize('NFKD', input).encode('ASCII', 'ignore')
def strip_accents(s):
   return ''.join(c for c in unicodedata.normalize('NFD', s)
                  if unicodedata.category(c) != 'Mn')

# %%
cities = []
for element in document.iterfind('country'):
    for subelement in element.getiterator('city'):
        name = subelement.find('name').text  
        if subelement.find('population') is None:
            pop = 'No data found'
        else:
            pop = int(subelement.find('population').text)
    cities.append((pop,name))
        
sorted(cities, key=itemgetter(0), reverse=True)
# Out:
# [('No data found', 'Focsani'),
#  ('No data found', 'Soroe'),
#  ('No data found', 'Gibraltar'),
#  ('No data found', 'Saint Peter Port'),
#  ('No data found', 'Saint Helier'),
#  ('No data found', 'Douglas'),
#  ('No data found', 'Longyearbyen'),
#  ('No data found', 'Dehra Dun'),
#  ('No data found', 'Putrajaya'),
#  ('No data found', 'Macao'),
#  ('No data found', 'Flying Fish Cove'),
#  ('No data found', 'West Island'),
#  ('No data found', 'Tabouk'),
#  ('No data found', 'Naha'),
#  ('No data found', 'The Valley'),
#  ('No data found', 'Oranjestad'),
#  ('No data found', 'Hamilton'),
#  ('No data found', 'Road Town'),
#  ('No data found', 'George Town'),
#  ('No data found', 'Chichica'),
#  ('No data found', u'San Jos\xe9 de las Lajas'),
#  ('No data found', 'Nuuk'),
#  ('No data found', 'Basse-Terre'),
#  ('No data found', 'Puerto Carreno'),
#  ('No data found', 'Grand Turk'),
#  ('No data found', 'Pago Pago'),
#  ('No data found', 'Avarua'),
#  ('No data found', 'Papeete'),
#  ('No data found', 'Agana'),
#  ('No data found', 'Yaren'),
#  ('No data found', 'Noumea'),
#  ('No data found', 'Alofi'),
#  ('No data found', 'Kingston'),
#  ('No data found', 'Saipan'),
#  ('No data found', 'Adamstown'),
#  ('No data found', 'Mata-Utu'),
#  ('No data found', 'Stanley'),
#  ('No data found', 'Tombouctou'),
#  ('No data found', 'Ngiva'),
#  ('No data found', 'Kindu'),
#  ('No data found', 'Mongu'),
#  ('No data found', 'Bondoukou'),
#  ('No data found', 'Geita'),
#  ('No data found', 'Mogadishu'),
#  ('No data found', 'Kaffrine'),
#  ('No data found', 'Bissau'),
#  ('No data found', 'Port Louis'),
#  ('No data found', 'Mamoutzou'),
#  ('No data found', 'Jamestown'),
#  (8092449, u'Ciudad de M\xe9xico'),
#  (7055071, 'Hong Kong'),
#  (2965403, 'Buenos Aires'),
#  (2106000, 'Toshkent'),
#  (2016681, 'Budapest'),
#  (1540000, 'Minsk'),
#  (1515889, u'Bras\xedlia'),
#  (1445929, 'Singapore'),
#  (1200000, 'Yerevan'),
#  (1158367, 'Nay Pyi Taw'),
#  (931591, 'Maputo'),
#  (900000, u'R\u012bga'),
#  (855000, 'Cape Town'),
#  (839566, u'Lom\xe9'),
#  (715334, 'Pointe-Noire'),
#  (707658, 'Tainan'),
#  (702000, u'Bayr\u016bt'),
#  (638432, 'Washington'),
#  (591985, 'Santiago'),
#  (587647, 'Colombo'),
#  (586930, 'Kingston'),
#  (582400, 'Dushanbe'),
#  (580544, 'Anyang'),
#  (548299, 'Port-of-Spain'),
#  (530965, "N'Djamena"),
#  (479500, 'Ulaanbaatar'),
#  (450000, 'Djibouti'),
#  (449477, 'Gaza'),
#  (421053, 'Monrovia'),
#  (400000, 'Phnom Penh'),
#  (380568, 'Asmara'),
#  (377409, 'Vientiane'),
#  (364096, 'As Sulaymaniyah'),
#  (357238, 'Banjul'),
#  (356000, u'Sevastopol\xb4'),
#  (333120, 'Blantyre'),
#  (328341, 'Astana'),
#  (310000, 'Canberra'),
#  (309771, 'Bobo Dioulasso'),
#  (298452, 'al Hudaydah'),
#  (288700, 'Mazar-i-Sharif'),
#  (283200, 'Sumgayit'),
#  (279237, 'Belfast'),
#  (277516, u'T\xe9touan'),
#  (274035, 'Chitungwiza'),
#  (265000, 'As Suways'),
#  (254146, 'Sariwon'),
#  (250645, 'Irbid'),
#  (250518, u'Ni\u0161'),
#  (242946, 'Paramaribo'),
#  (235440, 'Bujumbura'),
#  (232733, 'Kigali'),
#  (223844, 'Sousse'),
#  (223449, 'As Seeb'),
#  (222274, 'Ciudad del Este'),
#  (211045, 'Osh'),
#  (205504, 'Qianjiang'),
#  (198000, u'Zl\xedn'),
#  (194178, u"N'Z\xe9r\xe9kor\xe9"),
#  (192954, 'Klaipeda'),
#  (191116, 'San Miguel'),
#  (186011, 'Sittard-Geleen'),
#  (175441, 'Arica'),
#  (174717, 'Rach Gia'),
#  (172286, 'Pucallpa'),
#  (170107, 'Bandar Seri Begawan'),
#  (170000, 'Georgetown'),
#  (168164, 'Carolina'),
#  (167768, 'Kuwait'),
#  (167016, 'Eldoret'),
#  (163146, 'Hebron'),
#  (160862, 'Tartus'),
#  (154528, 'Jayapura'),
#  (148090, 'Prishtine'),
#  (147056, 'Windhoek'),
#  (146939, 'Ashdod'),
#  (145000, u'Al Man\u0101mah'),
#  (144461, u'Cob\xe1n'),
#  (143420, 'Stara Zagora'),
#  (141884, 'Al Fashir'),
#  (141500, 'Port Moresby'),
#  (137741, u'Castell\xf3n de la Plana'),
#  (136950, 'El Aaiun'),
#  (136473, 'Podgorica'),
#  (135783, 'Tarija'),
#  (134099, 'Djougou'),
#  (132393, 'Gusau'),
#  (131557, 'Saint-Denis'),
#  (125123, 'Al Sharjah'),
#  (125000, 'Willemstad'),
#  (123728, u'V\xe4ster\xe5s'),
#  (122669, u'B\u0103l\u0163i'),
#  (122307, 'Osmaniye'),
#  (119150, 'Sokhumi'),
#  (118038, 'Dunedin'),
#  (116989, u'S\xe1ssari'),
#  (116872, 'Villeurbanne'),
#  (114980, 'Juba'),
#  (114422, 'Santo Domingo de los Colorados'),
#  (109357, 'Sylhet'),
#  (108122, 'Maribor'),
#  (108000, 'Koszalin'),
#  (105910, 'Calapan'),
#  (105739, 'Jena'),
#  (105484, 'Kumanovo'),
#  (104269, 'Novyj Urengoj'),
#  (101503, 'Nassau'),
#  (100104, 'Catia La Mar'),
#  (100100, 'Tartu'),
#  (100000, 'Fort-de-France'),
#  (98118, 'Praia'),
#  (97516, 'Bridgetown'),
#  (94900, 'Mary'),
#  (94250, 'Lemesos'),
#  (93544, 'Biratnagar'),
#  (93394, 'Salto'),
#  (92988, u'Estel\xed'),
#  (92635, 'Tamanrasset'),
#  (91996, 'Al Rayyan'),
#  (86445, u'Cap-Ha\xeftien'),
#  (86340, 'Winterthur'),
#  (85193, 'Leuven'),
#  (81965, 'Mirpur Khas'),
#  (81798, 'Birjand'),
#  (80826, 'Toliara'),
#  (80309, 'Takoradi'),
#  (79056, 'Melilla'),
#  (76600, 'Luxembourg'),
#  (76343, 'Zadar'),
#  (75876, 'Magaria'),
#  (75573, 'Phuket'),
#  (75000, 'Maseru'),
#  (73182, 'Ceuta'),
#  (70286, 'Trnava'),
#  (69481, 'Suva'),
#  (69169, 'Hawassa'),
#  (67800, u'Lim\xf3n'),
#  (65244, 'Francistown'),
#  (64425, 'Yoro'),
#  (59768, 'Bo'),
#  (59069, 'Dili'),
#  (54275, 'Vaasa'),
#  (54023, 'Limerick'),
#  (52000, u'Kor\xe7\xeb'),
#  (51102, u'St. P\xf6lten'),
#  (50023, 'Bata'),
#  (49957, u'S\xe3o Tom\xe9'),
#  (49050, 'Belize City'),
#  (48922, 'Rosso'),
#  (46334, 'Male'),
#  (44111, 'Funchal'),
#  (42815, 'Misratah'),
#  (41406, u'Br\u010dko'),
#  (38290, 'Mbabane'),
#  (38091, 'Cayenne'),
#  (36735, 'Apia'),
#  (36717, 'Tarawa'),
#  (30365, 'Moroni'),
#  (30246, 'Franceville'),
#  (30000, "Saint George's"),
#  (26000, 'Honiara'),
#  (24970, 'Victoria'),
#  (24584, 'Buea'),
#  (23658, 'Nukualofa'),
#  (23453, 'Saint Johns'),
#  (20000, 'Thimphu'),
#  (15759, 'Port Vila'),
#  (15600, 'Andorra la Vella'),
#  (14700, 'Basseterre'),
#  (13000, 'Akureyri'),
#  (12909, 'Kingstown'),
#  (12346, u'T\xf3rshavn'),
#  (12331, 'Charlotte Amalie'),
#  (11791, 'Majuro'),
#  (11000, 'Roseau'),
#  (10751, 'Bimbo'),
#  (6524, 'Victoria'),
#  (6444, 'Palikir'),
#  (5961, 'Vadsoe'),
#  (5700, 'Marigot'),
#  (5618, 'Saint-Pierre'),
#  (4949, 'Vaduz'),
#  (4492, 'Funafuti'),
#  (4442, 'San Marino'),
#  (3661, 'Castries'),
#  (3565, 'Mukono'),
#  (3552, 'Iqaluit'),
#  (3500, 'Plymouth'),
#  (2299, 'Gustavia'),
#  (1338, 'Philipsburg'),
#  (1234, 'Monaco'),
#  (840, 'Vatican City'),
#  (490, 'Fakaofo'),
#  (391, 'Melekeok'),
#  (233, 'Karyes')]

# %% [markdown]
# Solution 3

# %%
groups = []
for element in document.iterfind('country'):
    name = element.find('name').text  
    if element.find('ethnicgroup') is None:
        ethnic = "No data available"
    else:
        per = element.find('ethnicgroup').attrib
        ethnic = element.find('ethnicgroup').text
    groups.append((per,ethnic,name))
        
sorted(groups, key=itemgetter(0), reverse=True)
# Out:
# [({'percentage': '99.7'}, 'Sotho', 'Lesotho'),
#  ({'percentage': '99.7'}, 'No data available', 'Madagascar'),
#  ({'percentage': '99.7'}, 'No data available', 'Malawi'),
#  ({'percentage': '99.4'}, 'Japanese', 'Japan'),
#  ({'percentage': '99.4'}, 'No data available', 'South Korea'),
#  ({'percentage': '99.4'}, 'No data available', 'Maldives'),
#  ({'percentage': '99.4'}, 'No data available', 'Oman'),
#  ({'percentage': '99'}, 'African', 'Benin'),
#  ({'percentage': '99'}, 'African', 'Nigeria'),
#  ({'percentage': '99'}, 'African', 'Togo'),
#  ({'percentage': '99'}, 'African', 'Gambia'),
#  ({'percentage': '98'}, 'Bengali', 'Bangladesh'),
#  ({'percentage': '97.7'}, 'Armenian', 'Armenia'),
#  ({'percentage': '97'}, 'European', 'Argentina'),
#  ({'percentage': '97'}, 'Berber Arab', 'Libya'),
#  ({'percentage': '96'}, 'Polynesian', 'Tuvalu'),
#  ({'percentage': '95'}, 'Albanian', 'Albania'),
#  ({'percentage': '95'}, 'Chinese', 'Hong Kong'),
#  ({'percentage': '95'}, 'Chinese', 'Macao'),
#  ({'percentage': '95'}, 'African', 'Haiti'),
#  ({'percentage': '95'}, 'Polynesian', 'Tokelau'),
#  ({'percentage': '95'}, 'Mestizo', 'Paraguay'),
#  ({'percentage': '95'}, 'Batswana', 'Botswana'),
#  ({'percentage': '95'}, 'Bantu', 'Tanzania'),
#  ({'percentage': '95'}, 'African', 'Liberia'),
#  ({'percentage': '94.9'}, 'Mongol', 'Mongolia'),
#  ({'percentage': '94.9'}, 'No data available', 'Nepal'),
#  ({'percentage': '93.5'}, 'Polynesian', 'Cook Islands'),
#  ({'percentage': '93.4'}, 'Finn', 'Finland'),
#  ({'percentage': '93'}, 'Greek', 'Greece'),
#  ({'percentage': '92.3'}, 'Hungarian', 'Hungary'),
#  ({'percentage': '92.3'}, 'No data available', 'Italy'),
#  ({'percentage': '92'}, 'Albanian', 'Kosovo'),
#  ({'percentage': '92'}, 'European', 'Australia'),
#  ({'percentage': '91.5'}, 'German', 'Germany'),
#  ({'percentage': '91.5'}, 'Han Chinese', 'China'),
#  ({'percentage': '91.1'}, 'Austrian', 'Austria'),
#  ({'percentage': '91'}, 'Slovene', 'Slovenia'),
#  ({'percentage': '90.6'}, 'Azeri', 'Azerbaijan'),
#  ({'percentage': '90.4'}, 'Czech', 'Czech Republic'),
#  ({'percentage': '90.3'}, 'Arab', 'Syria'),
#  ({'percentage': '90.3'}, 'African', 'Saint Lucia'),
#  ({'percentage': '90.1'}, 'Black', 'Anguilla'),
#  ({'percentage': '90.1'}, 'No data available', 'Antigua and Barbuda'),
#  ({'percentage': '90'}, 'Arab', 'Saudi Arabia'),
#  ({'percentage': '90'}, 'Mestizo', 'El Salvador'),
#  ({'percentage': '90'}, 'Mestizo', 'Honduras'),
#  ({'percentage': '90'}, 'African', 'Turks and Caicos Islands'),
#  ({'percentage': '90'}, 'No data available', 'Virgin Islands'),
#  ({'percentage': '89.6'}, 'Croat', 'Croatia'),
#  ({'percentage': '89.1'}, 'Romanian', 'Romania'),
#  ({'percentage': '88'}, 'European', 'Uruguay'),
#  ({'percentage': '87.4'}, 'Irish', 'Ireland'),
#  ({'percentage': '87.4'}, 'No data available', 'San Marino'),
#  ({'percentage': '85.7'}, 'Slovak', 'Slovakia'),
#  ({'percentage': '85.7'}, 'Viet/Kinh', 'Vietnam'),
#  ({'percentage': '85'}, 'Turkmen', 'Turkmenistan'),
#  ({'percentage': '85'}, 'Somali', 'Somalia'),
#  ({'percentage': '84.54'}, 'Turkish', 'Turkey'),
#  ({'percentage': '84.54'}, 'No data available', 'Denmark'),
#  ({'percentage': '84'}, 'Lithuanian', 'Lithuania'),
#  ({'percentage': '84'}, 'Mestizo', 'Panama'),
#  ({'percentage': '83.8'}, 'Georgian', 'Georgia'),
#  ({'percentage': '83.6'}, 'English', 'United Kingdom'),
#  ({'percentage': '83.4'}, 'Black', 'British Virgin Islands'),
#  ({'percentage': '83'}, 'Swede', 'Sweden'),
#  ({'percentage': '82.9'}, 'Serb', 'Serbia'),
#  ({'percentage': '82.5'}, 'Norwegian', 'Norway'),
#  ({'percentage': '81.2'}, 'Belorussian', 'Belarus'),
#  ({'percentage': '80.7'}, 'Dutch', 'Netherlands'),
#  ({'percentage': '80.2'}, 'White', 'Puerto Rico'),
#  ({'percentage': '80'}, 'Uzbek', 'Uzbekistan'),
#  ({'percentage': '80'}, 'European/Caribbean Amerindian', 'Aruba'),
#  ({'percentage': '80'}, 'No data available', 'Bahamas'),
#  ({'percentage': '80'}, 'Hutu', 'Rwanda'),
#  ({'percentage': '8.5'}, 'Fula', 'Niger'),
#  ({'percentage': '8'}, 'Chinese', 'Nauru'),
#  ({'percentage': '79.96'}, 'European', 'United States'),
#  ({'percentage': '79.9'}, 'Tajik', 'Tajikistan'),
#  ({'percentage': '79.8'}, 'Russian', 'Russia'),
#  ({'percentage': '78.2'}, 'Moldavian/Romanian', 'Moldova'),
#  ({'percentage': '78.2'}, 'No data available', 'Portugal'),
#  ({'percentage': '77.8'}, 'Ukrainian', 'Ukraine'),
#  ({'percentage': '77'}, 'Greek', 'Cyprus'),
#  ({'percentage': '76.9'}, 'Bulgarian', 'Bulgaria'),
#  ({'percentage': '76.4'}, 'Jewish', 'Israel'),
#  ({'percentage': '76.3'}, 'African', 'Jamaica'),
#  ({'percentage': '74'}, 'Sinhalese', 'Sri Lanka'),
#  ({'percentage': '74'}, 'Mestizo', 'Costa Rica'),
#  ({'percentage': '73'}, 'Mulatto', 'Dominican Republic'),
#  ({'percentage': '70'}, 'Chinese', 'Christmas Island'),
#  ({'percentage': '70'}, 'No data available', 'Cocos Islands'),
#  ({'percentage': '70'}, 'Arab', 'Sudan'),
#  ({'percentage': '70'}, 'No data available', 'South Sudan'),
#  ({'percentage': '70'}, 'No data available', 'Comoros'),
#  ({'percentage': '69'}, 'Mestizo', 'Nicaragua'),
#  ({'percentage': '68.7'}, 'Estonian', 'Estonia'),
#  ({'percentage': '68'}, 'Lao Loum', 'Laos'),
#  ({'percentage': '67.2'}, 'Christian', 'Falkland Islands'),
#  ({'percentage': '65.1'}, 'European', 'Cuba'),
#  ({'percentage': '65'}, 'German', 'Switzerland'),
#  ({'percentage': '65'}, 'Mestizo', 'Ecuador'),
#  ({'percentage': '64.9'}, 'Kyrgyz', 'Kyrgyzstan'),
#  ({'percentage': '64.2'}, 'Macedonian', 'Macedonia'),
#  ({'percentage': '63.1'}, 'Luxembourgish', 'Luxembourg'),
#  ({'percentage': '63.1'}, 'Kazakh', 'Kazakhstan'),
#  ({'percentage': '63.1'}, 'No data available', 'North Korea'),
#  ({'percentage': '60'}, 'Mestizo', 'Mexico'),
#  ({'percentage': '6.4'}, 'Indian', 'Singapore'),
#  ({'percentage': '6'}, 'Rwanda', 'Uganda'),
#  ({'percentage': '59.3'}, 'Latvian', 'Latvia'),
#  ({'percentage': '58'}, 'Fleming', 'Belgium'),
#  ({'percentage': '58'}, 'Mestizo', 'Colombia'),
#  ({'percentage': '56.8'}, 'European', 'New Zealand'),
#  ({'percentage': '56.3'}, 'Asian', 'Northern Mariana Islands'),
#  ({'percentage': '56.3'}, 'No data available', 'Palau'),
#  ({'percentage': '55.4'}, 'Norwegian', 'Svalbard'),
#  ({'percentage': '55'}, 'Tigrinya', 'Eritrea'),
#  ({'percentage': '54'}, 'Black', 'Bermuda'),
#  ({'percentage': '53.7'}, 'European', 'Brazil'),
#  ({'percentage': '50.4'}, 'Malay', 'Malaysia'),
#  ({'percentage': '50'}, 'Bhote', 'Bhutan'),
#  ({'percentage': '50'}, 'South Asian', 'United Arab Emirates'),
#  ({'percentage': '50'}, 'No data available', 'Yemen'),
#  ({'percentage': '50'}, 'Mestizo', 'Guatemala'),
#  ({'percentage': '50'}, 'Mande', 'Mali'),
#  ({'percentage': '50'}, 'African descent', 'Saint Helena'),
#  ({'percentage': '5'}, 'Italian', 'Liechtenstein'),
#  ({'percentage': '5'}, 'Chinese', 'Guadeloupe'),
#  ({'percentage': '5'}, 'Chinese', 'Martinique'),
#  ({'percentage': '5'}, 'No data available', 'Montserrat'),
#  ({'percentage': '5'}, 'No data available', 'Curacao'),
#  ({'percentage': '5'}, 'No data available', 'Sint Maarten'),
#  ({'percentage': '5'}, 'No data available', 'Saint Martin'),
#  ({'percentage': '5'}, 'No data available', 'Saint Barthelemy'),
#  ({'percentage': '5'}, 'Italian', 'Djibouti'),
#  ({'percentage': '48.7'}, 'Mestizo', 'Belize'),
#  ({'percentage': '48'}, 'Muslim', 'Bosnia and Herzegovina'),
#  ({'percentage': '47'}, 'French', 'Monaco'),
#  ({'percentage': '47'}, 'No data available', 'Gibraltar'),
#  ({'percentage': '46'}, 'Indian', 'Fiji'),
#  ({'percentage': '45'}, 'Javanese', 'Indonesia'),
#  ({'percentage': '45'}, 'No data available', 'Timor-Leste'),
#  ({'percentage': '45'}, 'No data available', 'Papua New Guinea'),
#  ({'percentage': '45'}, 'Amerindian', 'Peru'),
#  ({'percentage': '45'}, 'Mangbetu-Azande', 'Zaire'),
#  ({'percentage': '43.5'}, 'East Indian', 'Guyana'),
#  ({'percentage': '43'}, 'Montenegrin', 'Montenegro'),
#  ({'percentage': '43'}, 'Spanish', 'Andorra'),
#  ({'percentage': '43'}, 'No data available', 'France'),
#  ({'percentage': '4'}, 'Armenian', 'Lebanon'),
#  ({'percentage': '4'}, 'European', 'Barbados'),
#  ({'percentage': '4'}, 'French', 'Vanuatu'),
#  ({'percentage': '37.1'}, 'Chamorro', 'Guam'),
#  ({'percentage': '37'}, 'Hindustani', 'Suriname'),
#  ({'percentage': '37'}, 'No data available', 'Venezuela'),
#  ({'percentage': '35'}, 'Arab', 'Kuwait'),
#  ({'percentage': '34.5'}, 'Oromo', 'Ethiopia'),
#  ({'percentage': '34'}, 'Baya', 'Central African Republic'),
#  ({'percentage': '34'}, 'No data available', 'Chad'),
#  ({'percentage': '34'}, 'No data available', 'Equatorial Guinea'),
#  ({'percentage': '34'}, 'No data available', 'Gabon'),
#  ({'percentage': '30'}, 'Quechua', 'Bolivia'),
#  ({'percentage': '30'}, 'Maur', 'Mauritania'),
#  ({'percentage': '30'}, 'Malinke', 'Guinea'),
#  ({'percentage': '3'}, 'Arab', 'Iran'),
#  ({'percentage': '3'}, 'No data available', 'Pakistan'),
#  ({'percentage': '3'}, 'Amerindian', 'Chile'),
#  ({'percentage': '3'}, 'European', 'Swaziland'),
#  ({'percentage': '3'}, 'No data available', 'Reunion'),
#  ({'percentage': '28'}, 'British Isles', 'Canada'),
#  ({'percentage': '27'}, 'Creole', 'Mauritius'),
#  ({'percentage': '27'}, 'No data available', 'Mayotte'),
#  ({'percentage': '25'}, 'Tajik', 'Afghanistan'),
#  ({'percentage': '25'}, 'Dravidian', 'India'),
#  ({'percentage': '24'}, 'Mossi', 'Burkina Faso'),
#  ({'percentage': '20'}, 'Chinese', 'Brunei'),
#  ({'percentage': '20'}, 'Black', 'Cayman Islands'),
#  ({'percentage': '2.6'}, 'Indian', 'South Africa'),
#  ({'percentage': '2'}, 'Indian', 'Myanmar'),
#  ({'percentage': '2'}, 'Caucasian', 'American Samoa'),
#  ({'percentage': '18'}, 'Indian', 'Qatar'),
#  ({'percentage': '17'}, 'Jewish', 'West Bank'),
#  ({'percentage': '17'}, 'Fulani', 'Senegal'),
#  ({'percentage': '15'}, 'Kurdish', 'Iraq'),
#  ({'percentage': '14'}, 'Chinese', 'Thailand'),
#  ({'percentage': '14'}, 'Chinese', 'Taiwan'),
#  ({'percentage': '14'}, 'Danish', 'Greenland'),
#  ({'percentage': '13'}, 'African', 'Cameroon'),
#  ({'percentage': '12'}, 'Amerindian', 'French Guiana'),
#  ({'percentage': '11'}, 'Malinke', 'Cote dIvoire'),
#  ({'percentage': '100'}, 'Mediterranean Nordic', 'Spain'),
#  ({'percentage': '100'}, 'Scandinavian', 'Faroe Islands'),
#  ({'percentage': '100'}, 'Norman-French', 'Guernsey'),
#  ({'percentage': '100'}, 'No data available', 'Holy See'),
#  ({'percentage': '100'}, 'No data available', 'Ceuta'),
#  ({'percentage': '100'}, 'No data available', 'Melilla'),
#  ({'percentage': '100'}, 'Celt', 'Iceland'),
#  ({'percentage': '100'}, 'Norman-French', 'Jersey'),
#  ({'percentage': '100'}, 'No data available', 'Malta'),
#  ({'percentage': '100'}, 'No data available', 'Isle of Man'),
#  ({'percentage': '100'}, 'Carib Indians', 'Dominica'),
#  ({'percentage': '100'}, 'African', 'Grenada'),
#  ({'percentage': '100'}, 'African', 'Saint Kitts and Nevis'),
#  ({'percentage': '100'}, 'Basques Bretons', 'Saint Pierre and Miquelon'),
#  ({'percentage': '100'},
#   'No data available',
#   'Saint Vincent and the Grenadines'),
#  ({'percentage': '100'}, 'Micronesian', 'Kiribati'),
#  ({'percentage': '100'}, 'Micronesian', 'Marshall Islands'),
#  ({'percentage': '100'}, 'Polynesian', 'Micronesia'),
#  ({'percentage': '100'}, 'Polynesian', 'Niue'),
#  ({'percentage': '100'}, 'No data available', 'Norfolk Island'),
#  ({'percentage': '100'}, 'Bounty', 'Pitcairn'),
#  ({'percentage': '100'}, 'Polynesian', 'Wallis and Futuna'),
#  ({'percentage': '100'}, 'European', 'Sao Tome and Principe'),
#  ({'percentage': '100'}, 'Seychellois', 'Seychelles'),
#  ({'percentage': '10'}, 'Arab', 'Bahrain'),
#  ({'percentage': '10'}, 'French', 'French Polynesia'),
#  ({'percentage': '1.5'}, 'Chinese', 'Philippines'),
#  ({'percentage': '1.4'}, 'Vietnamese', 'New Caledonia'),
#  ({'percentage': '1.3'}, 'German', 'Poland'),
#  ({'percentage': '1.1'}, 'European', 'Zambia'),
#  ({'percentage': '1'}, 'Chinese', 'Cambodia'),
#  ({'percentage': '1'}, 'European', 'Egypt'),
#  ({'percentage': '1'}, 'Armenian', 'Jordan'),
#  ({'percentage': '1'}, 'Chinese', 'Trinidad and Tobago'),
#  ({'percentage': '1'}, 'European', 'Algeria'),
#  ({'percentage': '1'}, 'Jewish', 'Tunisia'),
#  ({'percentage': '1'}, 'No data available', 'Western Sahara'),
#  ({'percentage': '1'}, 'European', 'Angola'),
#  ({'percentage': '1'}, 'No data available', 'Congo'),
#  ({'percentage': '1'}, 'No data available', 'Namibia'),
#  ({'percentage': '1'}, 'Asian', 'Zimbabwe'),
#  ({'percentage': '1'}, 'European', 'Cape Verde'),
#  ({'percentage': '1'}, 'Arab', 'Kenya'),
#  ({'percentage': '1'}, 'European', 'Guinea-Bissau'),
#  ({'percentage': '1'}, 'Asian', 'Sierra Leone'),
#  ({'percentage': '0.6'}, 'Jewish', 'Gaza Strip'),
#  ({'percentage': '0.4'}, 'Europeans', 'Samoa'),
#  ({'percentage': '0.3'}, 'Chinese', 'Solomon Islands'),
#  ({'percentage': '0.3'}, 'No data available', 'Tonga'),
#  ({'percentage': '0.2'}, 'Jewish', 'Morocco'),
#  ({'percentage': '0.2'}, 'European', 'Ghana'),
#  ({'percentage': '0.2'}, 'No data available', 'Burundi'),
#  ({'percentage': '0.06'}, 'European', 'Mozambique')]
